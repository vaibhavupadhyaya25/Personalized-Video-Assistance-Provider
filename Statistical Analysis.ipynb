# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dt = pd.read_excel("Book12.xlsx")

# %%
dt.head()
# Out:
#       video_id trending_date  title length  \
# 0  n1WpP7iowLc      17.14.11            43
# 1  0dBIkQ4Mz1M      17.14.11            29
# 2  5qpjK5DgCt4      17.14.11            53
# 3  d380meD0W0M      17.14.11            24
# 4  2Vv-BfVoq4g      17.14.11            43
#
#                                                title channel_title  \
# 0        Eminem - Walk On Water (Audio) ft. Beyonc̩    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id  Unnamed: 6 publish_time  Weekdays  hours publish_time.1  \
# 0           10         NaN   2017-11-10         5     17     2017-11-10
# 1           23         NaN   2017-11-13         1     17     2017-11-13
# 2           23         NaN   2017-11-12         7     19     2017-11-12
# ...

# %%
dt=dt.drop(['Unnamed: 6'],axis=1)

# %%
dt.head()
# Out:
#       video_id trending_date  title length  \
# 0  n1WpP7iowLc      17.14.11            43
# 1  0dBIkQ4Mz1M      17.14.11            29
# 2  5qpjK5DgCt4      17.14.11            53
# 3  d380meD0W0M      17.14.11            24
# 4  2Vv-BfVoq4g      17.14.11            43
#
#                                                title channel_title  \
# 0        Eminem - Walk On Water (Audio) ft. Beyonc̩    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id publish_time  Weekdays  hours publish_time.1  Month  tag count  \
# 0           10   2017-11-10         5     17     2017-11-10     11          6
# 1           23   2017-11-13         1     17     2017-11-13     11         11
# ...

# %%
dt['category_id'].replace(24, 'Entertainment', inplace=True)
dt['category_id'].replace(29, 'Nonprofits & Activism', inplace=True)
dt['category_id'].replace(2 , 'Autos & Vehicles', inplace=True)
dt['category_id'].replace(1 , 'Film & Animation', inplace=True)
dt['category_id'].replace(10 , 'Music', inplace=True)
dt['category_id'].replace(15 , 'Pets & Animals', inplace=True)
dt['category_id'].replace(17 , 'Sports', inplace=True)
dt['category_id'].replace(18 , 'Short Movies', inplace=True)
dt['category_id'].replace(19 , 'Travel & Events', inplace=True)
dt['category_id'].replace(20 , 'Gaming', inplace=True)
dt['category_id'].replace(21 , 'Videoblogging', inplace=True)
dt['category_id'].replace(22 , 'People & Blogs', inplace=True)
dt['category_id'].replace(23, 'Comedy', inplace=True)
dt['category_id'].replace(25 , 'News & Politics', inplace=True)
dt['category_id'].replace(26 , 'Howto & Style', inplace=True)
dt['category_id'].replace(27 , 'Education', inplace=True)
dt['category_id'].replace(28 , 'Science & Technology', inplace=True)
dt['category_id'].replace(30 , 'Movies', inplace=True)
dt['category_id'].replace(31 , 'Anime/Animation', inplace=True)
dt['category_id'].replace(32 , 'Action/Adventure', inplace=True)
dt['category_id'].replace(33 , 'Classics', inplace=True)
dt['category_id'].replace(34 , 'Comedy', inplace=True)
dt['category_id'].replace(35 , 'Documentary', inplace=True)
dt['category_id'].replace(36 , 'Drama', inplace=True)
dt['category_id'].replace(37 , 'Family', inplace=True)
dt['category_id'].replace(38 , 'Foreign', inplace=True)
dt['category_id'].replace(39 , 'Horror', inplace=True)
dt['category_id'].replace(40 , 'Sci-Fi/Fantasy', inplace=True)
dt['category_id'].replace(41 , 'Thriller', inplace=True)
dt['category_id'].replace(42 , 'Shorts', inplace=True)
dt['category_id'].replace(43 , 'Shows', inplace=True)
dt['category_id'].replace(44 , 'Trailers', inplace=True)

# %%
dt.head(50)
# Out:
#        video_id trending_date  title length  \
# 0   n1WpP7iowLc      17.14.11            43
# 1   0dBIkQ4Mz1M      17.14.11            29
# 2   5qpjK5DgCt4      17.14.11            53
# 3   d380meD0W0M      17.14.11            24
# 4   2Vv-BfVoq4g      17.14.11            43
# 5   0yIWz1XEeyc      17.14.11            93
# 6   _uM5kFfkhB8      17.14.11            38
# 7   2kyS6SvSYSE      17.14.11            34
# 8   JzCsM1vtn78      17.14.11            36
# 9   43sm-QwLcx4      17.14.11            65
# 10  H1KBHFXm2Bg      17.14.11            47
# 11  U3xLOo-CNwo      17.14.11            62
# 12  FyZMnhUtLfE      17.14.11            80
# 13  7MxiQ4v0EnE      17.14.11            96
# 14  LUzsOyWp9lw      17.14.11            54
# 15  AS9-ITLhQxo      17.14.11            39
# 16  gifPYwArCVQ      17.14.11            30
# 17  8NHA23f7LvU      17.14.11            71
# 18  fy-CuCzaPp8      17.14.11            54
# 19  kzwfHumJyYc      17.14.11            81
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40881 entries, 0 to 40880
# Data columns (total 19 columns):
# video_id              40356 non-null object
# trending_date         40881 non-null object
# title length          40881 non-null int64
# title                 40881 non-null object
# channel_title         40881 non-null object
# category_id           40881 non-null object
# publish_time          40881 non-null datetime64[ns]
# Weekdays              40881 non-null int64
# hours                 40881 non-null int64
# publish_time.1        40881 non-null datetime64[ns]
# Month                 40881 non-null int64
# tag count             40881 non-null int64
# tags                  40881 non-null object
# views                 40881 non-null int64
# likes                 40881 non-null int64
# dislikes              40881 non-null int64
# comment_count         40881 non-null int64
# Description length    40870 non-null float64
# http count            40870 non-null float64
# ...

# %%
dt.shape
# Out:
# (40881, 19)

# %%
dt.describe()
# Out:
#        title length      Weekdays         hours         Month     tag count  \
# count  40881.000000  40881.000000  40881.000000  40881.000000  40881.000000
# mean      58.089871      3.971943     13.810670      5.273183     19.577652
# std       28.244172      1.969004      6.699009      3.852069     12.660718
# min        1.000000      1.000000      0.000000      1.000000      1.000000
# 25%       38.000000      2.000000     10.000000      2.000000     10.000000
# 50%       53.000000      4.000000     16.000000      4.000000     19.000000
# 75%       74.000000      6.000000     19.000000      6.000000     28.000000
# max      272.000000      7.000000     23.000000     12.000000    124.000000
#
#               views         likes      dislikes  comment_count  \
# count  4.088100e+04  4.088100e+04  4.088100e+04   4.088100e+04
# mean   1.147036e+06  3.958269e+04  2.009195e+03   5.042975e+03
# std    3.390913e+06  1.326895e+05  1.900837e+04   2.157902e+04
# ...

# %%
#check null values
print(dt.isnull().values.sum())
# Out:
# 547

# %%
print(dt.isnull().sum())
# Out:
# video_id              525
# trending_date           0
# title length            0
# title                   0
# channel_title           0
# category_id             0
# publish_time            0
# Weekdays                0
# hours                   0
# publish_time.1          0
# Month                   0
# tag count               0
# tags                    0
# views                   0
# likes                   0
# dislikes                0
# comment_count           0
# Description length     11
# http count             11
# dtype: int64

# %%
dt['Description length'].fillna((dt['Description length'].mean()), inplace=True)
dt['http count'].fillna((dt['http count'].mean()), inplace=True)

# %%
print(dt.isnull().sum())
# Out:
# video_id              525
# trending_date           0
# title length            0
# title                   0
# channel_title           0
# category_id             0
# publish_time            0
# Weekdays                0
# hours                   0
# publish_time.1          0
# Month                   0
# tag count               0
# tags                    0
# views                   0
# likes                   0
# dislikes                0
# comment_count           0
# Description length      0
# http count              0
# dtype: int64

# %%
dt['title length'].plot()

# %%
dt['http count'].plot()

# %%
dt2 = dt['Weekdays'].value_counts()
sb.set(style='white')
sb.barplot(dt2.index, dt2.values, alpha=1)
plt.title('Frequency distribution')
plt.ylabel('counts')
plt.xlabel('Weekdays')
# Out:
# Text(0.5,0,'Weekdays')

# %%
dt.boxplot('Month','category_id',rot=30, figsize=(14,6))

# %%
dt.boxplot('Weekdays','category_id',rot=30, figsize=(14,6))

# %%
dt3 = dt['hours'].value_counts()
sb.set(style='white')
sb.barplot(dt3.index, dt3.values, alpha=1)
plt.title('Frequency distribution in hours')
plt.ylabel('counts')
plt.xlabel('Weekdays')
# Out:
# Text(0.5,0,'Weekdays')

# %%
#examining the engagement
dt2['like_rate'] =  dt['likes'] / dt['views'] * 100
dt2['dislike_rate'] =  dt ['dislikes'] / dt['views'] * 100
dt2['comment_rate'] =  dt ['comment_count'] / dt['views'] * 100

# %%
plt.figure(figsize = (9,6))

g1 = sb.distplot(dt2['dislike_rate'], color='red',hist=False, label="Dislike")
g1 = sb.distplot(dt2['like_rate'], color='green',hist=False, label="Like")
g1 = sb.distplot(dt2['comment_rate'],hist=False,label="Comment")
g1.set_title('Engagements', fontsize=16)
plt.legend()
plt.show()

# %%
sb.lmplot(x='likes', y='views', data=dt)

# %%
sb.lmplot(x='dislikes', y='views', data=dt)

# %%
sb.lmplot(x='comment_count', y='views', data=dt)

# %%
#transfering features into another variables for correlation
dt1=dt
del dt1['Weekdays']
del dt1['hours']
del dt1['Month']

# %%
dt1.head()
# Out:
#    title length  tag count     views    likes  dislikes  comment_count  \
# 0            43          6  17158579   787425     43420         125882
# 1            29         11   1014651   127794      1688          13030
# 2            53         23   3191434   146035      5339           8181
# 3            24         14   2095828   132239      1989          17518
# 4            43         10  33523622  1634130     21082          85067
#
#    Description length  http count
# 0               595.0        14.0
# 1               722.0         9.0
# 2              1181.0        19.0
# 3               636.0         7.0
# 4              1256.0         7.0

# %%
dt1.corr()
# Out:
#                     title length  tag count     views     likes  dislikes  \
# title length            1.000000   0.157433 -0.037135 -0.105173 -0.017997
# tag count               0.157433   1.000000  0.002606 -0.029101  0.030053
# views                  -0.037135   0.002606  1.000000  0.828964  0.557621
# likes                  -0.105173  -0.029101  0.828964  1.000000  0.460427
# dislikes               -0.017997   0.030053  0.557621  0.460427  1.000000
# comment_count          -0.072288  -0.000045  0.693107  0.836585  0.643494
# Description length      0.133460   0.351866  0.010911 -0.002284  0.002118
# http count              0.020713   0.325262  0.013918  0.036590  0.010029
#
#                     comment_count  Description length  http count
# title length            -0.072288            0.133460    0.020713
# tag count               -0.000045            0.351866    0.325262
# views                    0.693107            0.010911    0.013918
# ...

# %%
Var_Corr = dt1.corr()
sb.heatmap(Var_Corr, xticklabels=Var_Corr.columns, yticklabels=Var_Corr.columns, annot=False)

# %%
X = dt1[['title length', 'tag count', 'likes','dislikes','comment_count', 'Description length', 'http count']]
Y = dt1['views']

# %%
X
# Out:
#        title length  tag count    likes  dislikes  comment_count  \
# 0                43          6   787425     43420         125882
# 1                29         11   127794      1688          13030
# 2                53         23   146035      5339           8181
# 3                24         14   132239      1989          17518
# 4                43         10  1634130     21082          85067
# 5                93         17   103755      4613          12143
# 6                38         25   187464      9850          26629
# 7                34          1    57534      2967          15959
# 8                36         28   292837      4123          36391
# 9                65          3     4135       976           1484
# 10               47         23   263596      8585          28976
# 11               62         20    28451      2285           3312
# 12               80         33      218        30            186
# ...

# %%
Y
# Out:
# 0        17158579
# 1         1014651
# 2         3191434
# 3         2095828
# 4        33523622
# 5         1309699
# 6         2987945
# 7          748374
# 8         4477587
# 9          505161
# 10        5068229
# 11        3153224
# 12         158815
# 13        5718766
# 14         960747
# 15        1531218
# 16         557883
# 17        1496225
# 18         308568
# 19        1096327
# 20         817732
# 21         343168
# 22        3905245
# 23        4204818
# 24         549374
# 25         348841
# 26         370827
# 27         653398
# 28          92280
# 29         178447
#            ...
# 40851     1615246
# 40852      266267
# 40853      950727
# 40854       94667
# 40855       42908
# 40856      109662
# 40857    16256855
# 40858      436795
# 40859      617135
# 40860     1780097
# 40861      812832
# 40862      345870
# 40863      191974
# 40864     2557709
# 40865     1392609
# 40866      293765
# 40867      104279
# 40868      793685
# 40869      168717
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])  
coeff_df
# Out:
#                      Coefficient
# title length         4467.880441
# tag count            4298.249643
# likes                  23.622387
# dislikes               56.744595
# comment_count         -46.220051
# Description length    122.267978
# http count         -17632.211456

# %%
Y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})

# %%
df
# Out:
#          Actual     Predicted
# 38057    169964  4.697907e+05
# 6392     167847  1.254434e+05
# 4783     389046  3.083054e+05
# 7168    1271839  3.820063e+05
# 5233     499083  7.430286e+05
# 33482     27518  2.472881e+05
# 18078    132443  4.354079e+05
# 14880    251862  2.229078e+05
# 31340   1617361  2.159512e+06
# 10664     87832  5.063898e+05
# 14449  23417389  2.067408e+07
# 4725     149662  4.371307e+05
# 12043   5711617  1.569544e+06
# 28009    146858  6.686966e+05
# 33053    601662  4.777407e+05
# 24223    676984  1.459415e+04
# 38764   4703085  4.997981e+06
# 18091     41352  5.384922e+05
# 25596    109801  4.863496e+05
# 2221     619446  7.839531e+05
# 31882    258981  1.513702e+06
# 16991    632436  3.557026e+05
# 12157    178579  4.840246e+05
# 39874     25651  2.030774e+05
# 8723    4176625  9.008855e+05
# 16793   1491029  7.217447e+05
# 23329    236598  6.847373e+05
# 32757    673534  6.281293e+05
# 15910    103935  4.706833e+05
# 10653    238630  2.047078e+05
# ...

# %%
print(regressor.score(X_test, Y_test))
# Out:
# 0.7239129149905555
